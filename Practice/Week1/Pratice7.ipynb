# %% [markdown]
# # ryan

# %%
str=input("enter the string")
count=0
dict={}
for i in str:
    if i=='a' or i=='A':
        count+=1
        dict[count]=i
    elif i=='e' or i=='E':
        count+=1
        dict[count]=i
    elif i=='i'or i=='I':
        count+=1
        dict[count]=i
    elif i=='o' or i=='O':
        count+=1
        dict[count]=i
    elif i=='u' or i=='U':
        count+=1
        dict[count]=i
print("Total Number of Vowel count is=> {count}")
print(f"Vowel are=>")
for indx in dict:
    print(f"{indx}=>{dict[indx]}")
# Out:
# enter the string Aryan
# Total Number of Vowel count is=> {count}
# Vowel are=>
# 1=>A
# 2=>a

# %%
list1=["Aryan","Swaraj","Atharv"]
list2=[]
for i in list1:
