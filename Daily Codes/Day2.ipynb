# %%
#string Functions

# %%
name = "Aryan"

# %%
name.lower()
# Out:
# 'aryan'

# %%
name
# Out:
# 'Aryan'

# %%
name = name.lower()

# %%
name
# Out:
# 'aryan'

# %%
name = name.upper()

# %%
name
# Out:
# 'ARYAN'

# %%
name.upper()
# Out:
# 'ARYAN'

# %%
name.title()
# Out:
# 'Aryan'

# %%
name = "Aryan"

# %%
name.swapcase()
# Out:
# 'aRYAN'

# %%
name.isupper()#if 1st Letter is capital and all letters are small then it return false
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1='ok'
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha() #it return true if all contents are alpahabets or otherwise return false
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit() #it  return true if the contents contains pure numericals otherwise return false
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()#combination of alpha and numeric it return true othr wise false
# Out:
# True

# %%
n = "?:"

# %%
n.isalnum()
# Out:
# False

# %%
name = " Pune "

# %%
print (name)
# Out:
#  Pune

# %%
name.startswith("P")
# Out:
# False

# %%
name.startswith(" P")
# Out:
# True

# %%
name.endswith(" Pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith("")
# Out:
# True

# %%
name.lstrip()# to remove left side spaces
# Out:
# 'Pune '

# %%
name.rstrip()#to remove right side sspaces
# Out:
# ' Pune'

# %%
name.strip()# to remove both sides  spaces
# Out:
# 'Pune'

# %%
len(name)# it also counts  spaces in string
# Out:
# 6

# %%
name.replace('u','oo')#if the string have same alphabet multiple time it will change first once /first occurence
# Out:
# ' Poone '

# %% [markdown]
# # Operators

# %%
# arithmetic

# %%
a =5
b =17

# %%
a + b #add
# Out:
# 22

# %%
a - b #sub
# Out:
# -12

# %%
a / b #div
# Out:
# 0.29411764705882354

# %%
a // b #floor div
# Out:
# 0

# %%
a * b #mul
# Out:
# 85

# %%
a ** b
# Out:
# 762939453125

# %%
a % b
# Out:
# 5

# %%
#assignment operators

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z+3

# %%
z
# Out:
# 17

# %%
z +=3

# %%
z
# Out:
# 11

# %%
z -= 3
z
# Out:
# 14

# %%
z*=3
z
# Out:
# 126

# %%
z/=3

# %%
z
# Out:
# 42.0

# %%
#comparison

# %%
a > b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#Logical Operators

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not b#operates on one operands becoz it is uniaryy
# Out:
# True

# %%
not a
# Out:
# False

# %%
# identity operators -> is ,isnot

# %%
a = 5
b = 5

# %%
id(a),id(b)# memory operators use see memory locations
# Out:
# (2192291420160, 2192291424320)

# %%
a is b
# Out:
# False

# %%
a = [3,4] #the value is stores in separate containers therefore the id are not same ie. memory locations
b= [3,4]

# %%
a is b
# Out:
# False

# %%
id(a),id(b)
# Out:
# (2192283644352, 2192291423296)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z
# Out:
# [3, 4]

# %%
z is a# it returns true becoze it take refrence of a not making another container for storage
# Out:
# True

# %%
a.append(5)

# %%
a
# Out:
# [3, 4, 5]

# %%
z
# Out:
# [3, 4, 5]

# %%
id(a),id(z)
# Out:
# (2192283644352, 2192283644352)

# %%
# memebership selection operators -> in ,not in

# %%
l = [1,2,4,3]

# %%
5 in l
# Out:
# False

# %%
1 in  l
# Out:
# True

# %%
2 not in l
# Out:
# False

# %% [markdown]
# # Precendence and association

# %%
#BODMAS

# %%
5 + 2-10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right association(used for raied to operations)
# Out:
# 256

# %%
2**8
# Out:
# 256

# %%
2 ** 3 //2
# Out:
# 4

# %%
# print function

# %%
name = "Aryan"
marks = 76.57

# %%
# my name is geet and marks are 76.57

# %%
print("my name is",name,"and marks",marks)
# Out:
# my name is Aryan and marks 76.57

# %%
print("my name is  %s and marks are %i" %(name, marks))
# Out:
# my name is  Aryan and marks are 76

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Aryan and marks are 76.57

# %%
# dir and help

# %%
dir(name);

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
# ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
# type casting

# %%
num1 = 34
num2 = 44.56
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num1)
# Out:
# 34

# %%
str(num1)
# Out:
# '34'

# %%
# write the program of two user input

# %%
a = int(input("enter the 1st number"))
b = int(input("enter the 2nd number"))

z = a + b

print("addition is =>", z)
# Out:
# enter the 1st number 1
# enter the 2nd number 101
# addition is => 102

# %%
"""
read the time in seconds as user input
and private the time in the format


eg ...
input -> 125 seconds
output -> 00:02:05

""";
