# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("student.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.shape
# Out:
# (10, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.head()# by default it will show first 5 data of file
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(7)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19

# %%
df.tail()# By default it will show ending 5 rows
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(7)
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.T# the colum becomes rows and rows become column by transpose
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
# Slicing 
''''
Panadas give two type of option for slicing one is index based and other is column based
for index based we use iloc method
an for column based we use

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df[1:4]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20

# %%
df.iloc[1:4]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20

# %%
df.iloc[1:4,1:4]# corrrect one we choice 1 row till 4 and same for other we start from 1 row  till 4 column
# Out:
#       name class  marks
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66

# %%
help(df.iloc())
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  .. deprecated:: 2.2.0
#  |
#  |     Returning a tuple from a callable is deprecated.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on
#  |    some value.
# ...

# %% [markdown]
# # First parameters are for rows and another one is for column for accessing

# %%
df.iloc[1:5,[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[[1,2,3,4,7],[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 7     8    amita  68.33

# %%
df.iloc[5,1]="geet"
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
#loc

# %%
df.loc[2:5,['name','class']]
# Out:
#       name class
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE

# %%
df.loc[0:9,['name']]
# Out:
#       name
# 0     anil
# 1     amit
# 2   aniket
# 3  ajinkya
# 4     asha
# 5     geet
# 6     amar
# 7    amita
# 8     amol
# 9    anmol

# %%
df.loc[0:9,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE
# 6     amar    BE
# 7    amita    BE
# 8     amol    TE
# 9    anmol    BE

# %%
# Methods on column&rows

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5       GEET
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.startswith('a')
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
df['name'].str.isupper()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, dtype: bool

# %%
df['name'].str.islower()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: name, dtype: bool

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %% [markdown]
# # Add Column

# %%
gender=['m','m','m','m','f','m','m','f','m','m']

# %%
df['gender']= gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      m
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 5     6     geet    BE  49.55   20      m
# 6     7     amar    BE  65.34   19      m
# 7     8    amita    BE  68.33   23      f
# 8     9     amol    TE  56.75   20      m
# 9    10    anmol    BE  78.66   21      m

# %% [markdown]
# # Modified column

# %%
df['roll']=df['roll']+100
df
# Out:
#    roll     name class  marks  age gender
# 0   201     anil    TE  56.77   22      m
# 1   202     amit    TE  59.77   21      m
# 2   203   aniket    BE  76.88   19      m
# 3   204  ajinkya    TE  69.66   20      m
# 4   205     asha    TE  63.28   20      f
# 5   206     geet    BE  49.55   20      m
# 6   207     amar    BE  65.34   19      m
# 7   208    amita    BE  68.33   23      f
# 8   209     amol    TE  56.75   20      m
# 9   210    anmol    BE  78.66   21      m

# %%
# aadd new column cgpa
# values should => marks/10+1.5

# %%
df["cgpa"] = df["marks"] / 10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 4   205     asha    TE  63.28   20      f  7.828
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %% [markdown]
# # Sorting By Values

# %%
df.sort_values(by='name')
# Out:
#    roll     name class  marks  age gender   cgpa
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 6   207     amar    BE  65.34   19      m  8.034
# 1   202     amit    TE  59.77   21      m  7.477
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 2   203   aniket    BE  76.88   19      m  9.188
# 0   201     anil    TE  56.77   22      m  7.177
# 9   210    anmol    BE  78.66   21      m  9.366
# 4   205     asha    TE  63.28   20      f  7.828
# 5   206     geet    BE  49.55   20      m  6.455

# %%
# sort by class and then marks simultaneouslyand check the result

# %%
df.sort_values(by=['class','marks'])
# Out:
#    roll     name class  marks  age gender   cgpa
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 2   203   aniket    BE  76.88   19      m  9.188
# 9   210    anmol    BE  78.66   21      m  9.366
# 8   209     amol    TE  56.75   20      m  7.175
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 4   205     asha    TE  63.28   20      f  7.828
# 3   204  ajinkya    TE  69.66   20      m  8.466

# %%
df['marks'].mean()
# Out:
# np.float64(64.499)

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df.describe()
# Out:
#             roll      marks        age       cgpa
# count   10.00000  10.000000  10.000000  10.000000
# mean   205.50000  64.499000  20.500000   7.949900
# std      3.02765   9.207179   1.269296   0.920718
# min    201.00000  49.550000  19.000000   6.455000
# 25%    203.25000  57.520000  20.000000   7.252000
# 50%    205.50000  64.310000  20.000000   7.931000
# 75%    207.75000  69.327500  21.000000   8.432750
# max    210.00000  78.660000  23.000000   9.366000

# %%
#groupby is use to grou the same category thing togethere

# %%
gr=df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   203  aniket    BE  76.88   19      m  9.188
# 5   206    geet    BE  49.55   20      m  6.455
# 6   207    amar    BE  65.34   19      m  8.034
# 7   208   amita    BE  68.33   23      f  8.333
# 9   210   anmol    BE  78.66   21      m  9.366

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 4   205     asha    TE  63.28   20      f  7.828
# 8   209     amol    TE  56.75   20      m  7.175

# %%
gt=df.groupby('gender')

# %%
gt.groups
# Out:
# {'f': [4, 7], 'm': [0, 1, 2, 3, 5, 6, 8, 9]}

# %%
gt.get_group('m')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
gt.get_group('f')
# Out:
#    roll   name class  marks  age gender   cgpa
# 4   205   asha    TE  63.28   20      f  7.828
# 7   208  amita    BE  68.33   23      f  8.333

# %%
gr.min()
# Out:
#        roll     name  marks  age gender   cgpa
# class
# BE      203     amar  49.55   19      f  6.455
# TE      201  ajinkya  56.75   20      f  7.175

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %% [markdown]
# # Boolean filtering

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 4   205     asha    TE  63.28   20      f  7.828
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age gender   cgpa
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 4   205     asha    TE  63.28   20      f  7.828
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
# filter the data of those student->marks>60 and belong to be class

# %%
f = df[(df['marks'] > 60) & (df['class'] == 'BE')]    
f
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   203  aniket    BE  76.88   19      m  9.188
# 6   207    amar    BE  65.34   19      m  8.034
# 7   208   amita    BE  68.33   23      f  8.333
# 9   210   anmol    BE  78.66   21      m  9.366

# %% [markdown]
# # Drops Rows and Column

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
df.drop([4,5,6])
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
#drop name column

# %%
df.drop(columns=['name'])
# Out:
#    roll class  marks  age gender   cgpa
# 0   201    TE  56.77   22      m  7.177
# 1   202    TE  59.77   21      m  7.477
# 2   203    BE  76.88   19      m  9.188
# 3   204    TE  69.66   20      m  8.466
# 4   205    TE  63.28   20      f  7.828
# 5   206    BE  49.55   20      m  6.455
# 6   207    BE  65.34   19      m  8.034
# 7   208    BE  68.33   23      f  8.333
# 8   209    TE  56.75   20      m  7.175
# 9   210    BE  78.66   21      m  9.366

# %%
df.drop('name',axis=1)
# Out:
#    roll class  marks  age gender   cgpa
# 0   201    TE  56.77   22      m  7.177
# 1   202    TE  59.77   21      m  7.477
# 2   203    BE  76.88   19      m  9.188
# 3   204    TE  69.66   20      m  8.466
# 4   205    TE  63.28   20      f  7.828
# 5   206    BE  49.55   20      m  6.455
# 6   207    BE  65.34   19      m  8.034
# 7   208    BE  68.33   23      f  8.333
# 8   209    TE  56.75   20      m  7.175
# 9   210    BE  78.66   21      m  9.366

# %%
df.drop (['name','class'],axis=1)
# Out:
#    roll  marks  age gender   cgpa
# 0   201  56.77   22      m  7.177
# 1   202  59.77   21      m  7.477
# 2   203  76.88   19      m  9.188
# 3   204  69.66   20      m  8.466
# 4   205  63.28   20      f  7.828
# 5   206  49.55   20      m  6.455
# 6   207  65.34   19      m  8.034
# 7   208  68.33   23      f  8.333
# 8   209  56.75   20      m  7.175
# 9   210  78.66   21      m  9.366

# %% [markdown]
# # To make chnages in permanent table we have  to use inplace=True

# %%
df.drop (['gender','cgpa'],axis=1,inplace=True)

# %%
df
# Out:
#    roll     name class  marks  age
# 0   201     anil    TE  56.77   22
# 1   202     amit    TE  59.77   21
# 2   203   aniket    BE  76.88   19
# 3   204  ajinkya    TE  69.66   20
# 4   205     asha    TE  63.28   20
# 5   206     geet    BE  49.55   20
# 6   207     amar    BE  65.34   19
# 7   208    amita    BE  68.33   23
# 8   209     amol    TE  56.75   20
# 9   210    anmol    BE  78.66   21

# %%
# create a dataframe
# columns->roll,gender,cgpa
#roll column will have same values as that of in the df dataframe

# %%
import pandas as pd

df2 = pd.DataFrame({
    'roll': df['roll'],
    'gender': ['M', 'F', 'M', 'F', 'M','M', 'F', 'M', 'F', 'M'], 
    'cgpa': [8.2, 9.1, 7.8, 8.9, 8.5,8.2, 9.1, 7.8, 8.9, 8.0]    
})

# %%
df2
# Out:
#    roll gender  cgpa
# 0   201      M   8.2
# 1   202      F   9.1
# 2   203      M   7.8
# 3   204      F   8.9
# 4   205      M   8.5
# 5   206      M   8.2
# 6   207      F   9.1
# 7   208      M   7.8
# 8   209      F   8.9
# 9   210      M   8.0

# %%
df2 = pd.DataFrame({
    'roll': df['roll'],
    'gender': gender, 
    'cgpa': df['marks']/10+1.5   
})

# %%
df2
# Out:
#    roll gender   cgpa
# 0   201      m  7.177
# 1   202      m  7.477
# 2   203      m  9.188
# 3   204      m  8.466
# 4   205      f  7.828
# 5   206      m  6.455
# 6   207      m  8.034
# 7   208      f  8.333
# 8   209      m  7.175
# 9   210      m  9.366

# %%
df2
# Out:
#    roll gender   cgpa
# 0   201      m  7.177
# 1   202      m  7.477
# 2   203      m  9.188
# 3   204      m  8.466
# 4   205      f  7.828
# 5   206      m  6.455
# 6   207      m  8.034
# 7   208      f  8.333
# 8   209      m  7.175
# 9   210      m  9.366

# %%
pd.merge(df,df2)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   201     anil    TE  56.77   22      m  7.177
# 1   202     amit    TE  59.77   21      m  7.477
# 2   203   aniket    BE  76.88   19      m  9.188
# 3   204  ajinkya    TE  69.66   20      m  8.466
# 4   205     asha    TE  63.28   20      f  7.828
# 5   206     geet    BE  49.55   20      m  6.455
# 6   207     amar    BE  65.34   19      m  8.034
# 7   208    amita    BE  68.33   23      f  8.333
# 8   209     amol    TE  56.75   20      m  7.175
# 9   210    anmol    BE  78.66   21      m  9.366

# %%
#cocat

# %%
#load student5.csv

# %%
df2
# Out:
#    roll gender   cgpa
# 0   201      m  7.177
# 1   202      m  7.477
# 2   203      m  9.188
# 3   204      m  8.466
# 4   205      f  7.828
# 5   206      m  6.455
# 6   207      m  8.034
# 7   208      f  8.333
# 8   209      m  7.175
# 9   210      m  9.366

# %%
df1=pd.read_csv('student5.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df1 ,df2], ignore_index= True)
# Out:
#     roll     name class  marks   age gender   cgpa
# 0      1   surbhi    TE  67.44  23.0    NaN    NaN
# 1      2    sujay    TE  74.12  22.0    NaN    NaN
# 2      3  subhash    BE  82.44  21.0    NaN    NaN
# 3      4   sachin    TE  59.33  21.0    NaN    NaN
# 4      5  shalini    TE  63.45  20.0    NaN    NaN
# 5    201      NaN   NaN    NaN   NaN      m  7.177
# 6    202      NaN   NaN    NaN   NaN      m  7.477
# 7    203      NaN   NaN    NaN   NaN      m  9.188
# 8    204      NaN   NaN    NaN   NaN      m  8.466
# 9    205      NaN   NaN    NaN   NaN      f  7.828
# 10   206      NaN   NaN    NaN   NaN      m  6.455
# 11   207      NaN   NaN    NaN   NaN      m  8.034
# 12   208      NaN   NaN    NaN   NaN      f  8.333
# 13   209      NaN   NaN    NaN   NaN      m  7.175
# 14   210      NaN   NaN    NaN   NaN      m  9.366

# %%
f = df[(df['marks'] > 60) & (df['class'] == 'BE')]

# %%
f.to_csv('op_csv',index= False)
