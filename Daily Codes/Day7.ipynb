# %% [markdown]
# # String Operation

# %%
sent="Hello World!"
sent
# Out:
# 'Hello World!'

# %%
sent='Hello World!'
sent
# Out:
# 'Hello World!'

# %%
# Docstring

# %%
sent="""
this is multi-line-string
Iyt can span multile lines.
It is often used for doccstrings.

"""

# %%
sent
# Out:
# '\nthis is multi-line-string\nIyt can span multile lines.\nIt is often used for doccstrings.\n\n'

# %%
print(sent)
# Out:
# this is multi-line-string
# Iyt can span multile lines.
# It is often used for doccstrings.

# %%
sent ="hello python"

# %%
sent[0] #indexxing & Spaces  also have index
# Out:
# 'h'

# %%
sent[0:5] #slicing
# Out:
# 'hello'

# %%
#take a string as user inuput 
#print the output =>index and character

# %%
str=input("Enter the string:")
count=0
for i in str:
    print(f"{count}=>{i}")
    count=count+1
# Out:
# Enter the string: Roses Are Red
# 0=>R
# 1=>o
# 2=>s
# 3=>e
# 4=>s
# 5=>
# 6=>A
# 7=>r
# 8=>e
# 9=>
# 10=>R
# 11=>e
# 12=>d

# %%
sent ="ajit kumar;age:25;city:delhi;hobby:coding"

# %%
type(sent)
# Out:
# str

# %%
sent.split(";")# its splits after semicolons.
# Out:
# ['ajit kumar', 'age:25', 'city:delhi', 'hobby:coding']

# %%
sent.find("kumar")#include space also
# Out:
# 5

# %%
sent.find("k")
# Out:
# 5

# %%
s1="hello"
s1.find("l")
# Out:
# 2

# %%
s1="hello"
s1.find("llo")
# Out:
# 2

# %%
0# split=> it splits the string based on the given delimeter and returns a list of substrings.


#join -> opposite of split

# %%
l=["hello", "world", "python"]

# %%
' '.join(l)
# Out:
# 'hello world python'

# %%
'=='.join(l)
# Out:
# 'hello==world==python'

# %%
l.count('l')
# Out:
# 0

# %%
# user in-> string
#using loop split into individuals characters and store in a list

# %%
str=input("Enter string")
list=[]
for i in str:
    list.append(i)
print(list)
# Out:
# Enter string aryan
# ['a', 'r', 'y', 'a', 'n']

# %%
""""
take user input chacter1 character2 character z
use a loop and if-else to check if a specific character is present in the string or not.
get output for both if the character is present and if it is not present.
take 2 character to check in string
""";

# %%
str=input("enter a string")
ch1=input("enter a character")
ch2=input("enter a character")
flag1=0
flag2=0
for i in str:
   if ch1==i:
       flag1=1
   if ch2 in str:
       flag2=1
if flag1==1:
    print("Character1 is Present")
if flag2==1:
    print("Character2 is Present")
if flag1==0:
    print("Ch1 is absent")
if flag2==0:
    print("Ch2 is absent")
# Out:
# enter a string Aryan
# enter a character a
# enter a character r
# Character1 is Present
# Character2 is Present

# %% [markdown]
# # Escape sequences

# %%
print(" I like Python Programming \n its easy")
# Out:
#  I like Python Programming
#  its easy

# %%
print(" I like Python Programming \t its easy")
# Out:
#  I like Python Programming 	 its easy

# %%
print(" I like Python Programming \ its easy")
# Out:
#  I like Python Programming \ its easy

# %%
print(" I like Python programming \\ its easy")
# Out:
#  I like Python programming \ its easy

# %%
print(" I like Python programming \"its easy") # without closing the string using double code we use blackslach to escape sequence
# Out:
#  I like Python programming "its easy

# %%
name='aryan'
marks=90

# %%
"my name is {} and my marks are{}".format(name,marks)
# Out:
# 'my name is aryan and my marks are90'
