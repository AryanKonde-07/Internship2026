# %%
# open the file
f = open("untitled.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='untitled.txt' mode='r' encoding='cp65001'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# '"Atoms of radioactive elements can split. According to Albert Einstein, mass and energy are interchangeable under certain circumstances. When atoms split, the process is called nuclear fission. In this case, a small amount of mass is converted into energy. Thus the energy released cannot do much damage. However, several subatomic particles called neutrons are also emitted during this process. Each neutron will hit a radioactive element releasing more neutrons in the process. This causes a chain reaction and creates a large amount of energy. This energy is converted into heat which expands uncontrollably causing an explosion. Hence, atoms do not literally explode. They generate energy that can cause explosions."\n'

# %%
f = open("untitled.txt")

# %%
f.readline(10)
# Out:
# 'Atoms of r'

# %%
f.readline(5)
# Out:
# 'adioa'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(5)
# Out:
# 'adioa'

# %%
f.readlines()
# Out:
# ['ctive elements can split. According to Albert Einstein, mass and energy are interchangeable under certain circumstances. When atoms split, the process is called nuclear fission. In this case, a small amount of mass is converted into energy. Thus the energy released cannot do much damage. However, several subatomic particles called neutrons are also emitted during this process. Each neutron will hit a radioactive element releasing more neutrons in the process. This causes a chain reaction and creates a large amount of energy. This energy is converted into heat which expands uncontrollably causing an explosion. Hence, atoms do not literally explode. They generate energy that can cause explosions.\n',
#  '\n']

# %%
f = open("untitled.txt")

# %%
data=f.readlines()

# %%
data
# Out:
# ['Atoms of radioactive elements can split. According to Albert Einstein, mass and energy are interchangeable under certain circumstances. When atoms split, the process is called nuclear fission. In this case, a small amount of mass is converted into energy. Thus the energy released cannot do much damage. However, several subatomic particles called neutrons are also emitted during this process. Each neutron will hit a radioactive element releasing more neutrons in the process. This causes a chain reaction and creates a large amount of energy. This energy is converted into heat which expands uncontrollably causing an explosion. Hence, atoms do not literally explode. They generate energy that can cause explosions.\n',
#  '\n']

# %%
for line in data:
    print(line)
# Out:
# Atoms of radioactive elements can split. According to Albert Einstein, mass and energy are interchangeable under certain circumstances. When atoms split, the process is called nuclear fission. In this case, a small amount of mass is converted into energy. Thus the energy released cannot do much damage. However, several subatomic particles called neutrons are also emitted during this process. Each neutron will hit a radioactive element releasing more neutrons in the process. This causes a chain reaction and creates a large amount of energy. This energy is converted into heat which expands uncontrollably causing an explosion. Hence, atoms do not literally explode. They generate energy that can cause explosions.

# %%
for line in data:
    print(line.upper())
# Out:
# ATOMS OF RADIOACTIVE ELEMENTS CAN SPLIT. ACCORDING TO ALBERT EINSTEIN, MASS AND ENERGY ARE INTERCHANGEABLE UNDER CERTAIN CIRCUMSTANCES. WHEN ATOMS SPLIT, THE PROCESS IS CALLED NUCLEAR FISSION. IN THIS CASE, A SMALL AMOUNT OF MASS IS CONVERTED INTO ENERGY. THUS THE ENERGY RELEASED CANNOT DO MUCH DAMAGE. HOWEVER, SEVERAL SUBATOMIC PARTICLES CALLED NEUTRONS ARE ALSO EMITTED DURING THIS PROCESS. EACH NEUTRON WILL HIT A RADIOACTIVE ELEMENT RELEASING MORE NEUTRONS IN THE PROCESS. THIS CAUSES A CHAIN REACTION AND CREATES A LARGE AMOUNT OF ENERGY. THIS ENERGY IS CONVERTED INTO HEAT WHICH EXPANDS UNCONTROLLABLY CAUSING AN EXPLOSION. HENCE, ATOMS DO NOT LITERALLY EXPLODE. THEY GENERATE ENERGY THAT CAN CAUSE EXPLOSIONS.

# %%
#read function

# %%
f = open("untitled.txt")

# %%
text=f.read()

# %%
text
# Out:
# 'Atoms of radioactive elements can split. According to Albert Einstein, mass and energy are interchangeable under certain circumstances. When atoms split, the process is called nuclear fission. In this case, a small amount of mass is converted into energy. Thus the energy released cannot do much damage. However, several subatomic particles called neutrons are also emitted during this process. Each neutron will hit a radioactive element releasing more neutrons in the process. This causes a chain reaction and creates a large amount of energy. This energy is converted into heat which expands uncontrollably causing an explosion. Hence, atoms do not literally explode. They generate energy that can cause explosions.\n\n'

# %%
text.split()
# Out:
# ['Atoms',
#  'of',
#  'radioactive',
#  'elements',
#  'can',
#  'split.',
#  'According',
#  'to',
#  'Albert',
#  'Einstein,',
#  'mass',
#  'and',
#  'energy',
#  'are',
#  'interchangeable',
#  'under',
#  'certain',
#  'circumstances.',
#  'When',
#  'atoms',
#  'split,',
#  'the',
#  'process',
#  'is',
#  'called',
#  'nuclear',
#  'fission.',
#  'In',
#  'this',
#  'case,',
#  'a',
#  'small',
#  'amount',
#  'of',
#  'mass',
#  'is',
#  'converted',
#  'into',
#  'energy.',
#  'Thus',
#  'the',
#  'energy',
#  'released',
#  'cannot',
#  'do',
#  'much',
#  'damage.',
#  'However,',
#  'several',
#  'subatomic',
#  'particles',
#  'called',
#  'neutrons',
#  'are',
#  'also',
#  'emitted',
#  'during',
#  'this',
#  'process.',
#  'Each',
#  'neutron',
#  'will',
#  'hit',
#  'a',
#  'radioactive',
#  'element',
#  'releasing',
#  'more',
#  'neutrons',
#  'in',
#  'the',
#  'process.',
#  'This',
#  'causes',
#  'a',
#  'chain',
#  'reaction',
#  'and',
#  'creates',
# ...

# %%
f=open("sample.txt")

# %%
print(f.read())
# Out:
# माझी आई जगातील सर्वात चांगली आई आहे.
# माझी आई माझ्यासाठी सर्वात महत्वपूर्ण आहे.
# माझी आई मला खूप प्रेम करते.
# ती माझ्यासाठी स्वादिष्ट व्यंजन बनवते.
# मला रोज सकाळी शाळेत जाण्यासाठी तयार करते.
# माझी आई मला अभ्यासात मदत करते.
# मी सुद्धा घराच्या कामात आईला मदत करतो.
# माझी आई मला चांगल्या गोष्टी शिकवते.
# माझी आई मला दररोज छान छान गोष्टी सांगते.
#  माझी आई मला प्रेमाने दादू म्हणते.

# %%
f.close()

# %%
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 print(f.read())
#
# ValueError: I/O operation on closed file.

# %%
# opening a fie with context manager

# %%
with open ("sample.txt") as f:
    data=f.read()

# %%
f.close()

# %%
data
# Out:
# 'माझी आई जगातील सर्वात चांगली आई आहे.\nमाझी आई माझ्यासाठी सर्वात महत्वपूर्ण आहे.\nमाझी आई मला खूप प्रेम करते.\nती माझ्यासाठी स्वादिष्ट व्यंजन बनवते.\nमला रोज सकाळी शाळेत जाण्यासाठी तयार करते.\nमाझी आई मला अभ्यासात मदत करते.\nमी सुद्धा घराच्या कामात आईला मदत करतो.\nमाझी आई मला चांगल्या गोष्टी शिकवते.\nमाझी आई मला दररोज छान छान गोष्टी सांगते.\n माझी आई मला प्रेमाने दादू म्हणते.'

# %%
# writing in a file

# %%
f=open("my.txt",'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
line=["frodo took the ring.","he started his journey to mount doom"]

# %%
f.writelines(line)

# %%
f.close()

# %%
# writelines=> takes the list of sentences from user and writes in the file

# %%
#write()

# %%
sent="Frodo took the ring.,he started his journey to mount doom"

# %%
f=open("my.txt",'w')
f.write(sent)
f.close()

# %%
#write into a myfile.txt with context manager
#use write function and add 3 separate lines

# %%
with open ("my.txt",'w') as f:
    line="Frodo took the ring.,\nhe started his journey to mount doom,\nAryan is good person"
    data=f.write(line)

# %%
#simple file copy operation

# %%
s=open('sample.txt','r')
f=open ('my.txt','w')

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
#append

# %%
s=open('sample.txt','a')

# %%
s.write('\ndone')
# Out:
# 5

# %%
s.close()
