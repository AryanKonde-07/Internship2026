# %%
print("Hello World")
# Out:
# Hello World

# %%
#add above ->A, below ->B  del->X

# %%
add above -> A,below -> B del->X
# Out:
#   Cell In[4], line 1
#     add above -> A,below -> B del->X
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # identifiers

# %%
num = 56

# %%
num = 8

# %%
NAME = "SHIVAM"

# %%
print(NAME)
# Out:
# SHIVAM

# %%
NAME
# Out:
# 'SHIVAM'

# %%
rate of Interest =5
# Out:
#   Cell In[11], line 1
#     rate of Interest =5
#          ^
# SyntaxError: invalid syntax

# %%
rate_of_Interest = 5

# %%
rate_of_Interest
# Out:
# 5

# %%
pass = 28
# Out:
#   Cell In[16], line 1
#     pass = 28
#          ^
# SyntaxError: invalid syntax

# %%
Pass = 28

# %%
Pass
# Out:
# 28

# %%
l = 3

# %%
type(l)
# Out:
# int

# %%
s="Aryan"

# %%
type(s)
# Out:
# str

# %%
a = 32.22

# %%
type(a)
# Out:
# float

# %%
nuum = 218912864424**234
nuum
# Out:
# ...

# %%
#float

# %%
num = 23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0

# %%
#string

# %%
sent = "I Like Python Programming"

# %%
sent
# Out:
# 'I Like Python Programming'

# %%
print(sent)
# Out:
# I Like Python Programming

# %%
sent = ('I Like "Python" Programming')

# %%
sent
# Out:
# 'I Like "Python" Programming'

# %%
sent = ("I Like 'Python' Programmming")

# %%
sent
# Out:
# "I Like 'Python' Programmming"

# %%
a= 3 ; b= 4 
result = a+b
print(result)
# Out:
# 7

# %%
result
# Out:
# 7

# %%
a,b,c =23,56,"ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'
